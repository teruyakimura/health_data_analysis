# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
stress_df = pd.read_csv('Stress_Dataset.csv')

# %%
stress_level_df = pd.read_csv('StressLevelDataset.csv')

# %%
stress_level_df.head(5)
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
stress_level_df.shape
# Out:
# (1100, 21)

# %%
stress_level_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %%
stress_level_df.describe().T
# Out:
#                                count       mean       std  min   25%   50%  \
# anxiety_level                 1100.0  11.063636  6.117558  0.0   6.0  11.0
# self_esteem                   1100.0  17.777273  8.944599  0.0  11.0  19.0
# mental_health_history         1100.0   0.492727  0.500175  0.0   0.0   0.0
# depression                    1100.0  12.555455  7.727008  0.0   6.0  12.0
# headache                      1100.0   2.508182  1.409356  0.0   1.0   3.0
# blood_pressure                1100.0   2.181818  0.833575  1.0   1.0   2.0
# sleep_quality                 1100.0   2.660000  1.548383  0.0   1.0   2.5
# breathing_problem             1100.0   2.753636  1.400713  0.0   2.0   3.0
# noise_level                   1100.0   2.649091  1.328127  0.0   2.0   3.0
# living_conditions             1100.0   2.518182  1.119208  0.0   2.0   2.0
# safety                        1100.0   2.737273  1.406171  0.0   2.0   2.0
# ...

# %%
stress_level_df.groupby('mental_health_history').count()
# Out:
#                        anxiety_level  self_esteem  depression  headache  \
# mental_health_history
# 0                                558          558         558       558
# 1                                542          542         542       542
#
#                        blood_pressure  sleep_quality  breathing_problem  \
# mental_health_history
# 0                                 558            558                558
# 1                                 542            542                542
#
#                        noise_level  living_conditions  safety  basic_needs  \
# mental_health_history
# 0                              558                558     558          558
# 1                              542                542     542          542
#
#                        academic_performance  study_load  \
# mental_health_history
# 0                                       558         558
# 1                                       542         542
#
# ...

# %%
stress_df.head(5)
# Out:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
# 2       0   20                                                  5
# 3       1   20                                                  3
# 4       0   20                                                  3
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# ...

# %%
stress_df.shape
# Out:
# (843, 26)

# %%
stress_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 26 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Gender                                                                843 non-null    int64
#  1   Age                                                                   843 non-null    int64
#  2   Have you recently experienced stress in your life?                    843 non-null    int64
#  3   Have you noticed a rapid heartbeat or palpitations?                   843 non-null    int64
#  4   Have you been dealing with anxiety or tension recently?               843 non-null    int64
#  5   Do you face any sleep problems or difficulties falling asleep?        843 non-null    int64
# ...

# %%
stress_df.describe().T
# Out:
#                                                     count       mean  \
# Gender                                              843.0   0.349941
# Age                                                 843.0  20.071174
# Have you recently experienced stress in your life?  843.0   2.997628
# Have you noticed a rapid heartbeat or palpitati...  843.0   2.755635
# Have you been dealing with anxiety or tension r...  843.0   2.543298
# Do you face any sleep problems or difficulties ...  843.0   2.786477
# Have you been dealing with anxiety or tension r...  843.0   2.663108
# Have you been getting headaches more often than...  843.0   2.628707
# Do you get irritated easily?                        843.0   2.702254
# Do you have trouble concentrating on your acade...  843.0   2.699881
# Have you been feeling sadness or low mood?          843.0   2.584816
# Have you been experiencing any illness or healt...  843.0   2.549229
# Do you often feel lonely or isolated?               843.0   2.497034
# ...
